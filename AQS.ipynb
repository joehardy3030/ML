# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
AQS_raw_url = "https://aqs.epa.gov/api/rawData?"
username_password = "user=jlhardyphd@gmail.com&pw=orangemouse54"
parameters = "&format=DMCSV&param=44201&bdate=20110501&edate=20110501&state=37&county=063"
query_url = AQS_raw_url + username_password + parameters

# %%
df_raw_data = pd.read_csv(query_url)
df_raw_data
# Out:
#        Latitude  Longitude  Datum  Horizontal Accuracy  State Code  \
# 0     36.032955 -78.904037  NAD83                 3.04        37.0
# 1     36.032955 -78.904037  NAD83                 3.04        37.0
# 2     36.032955 -78.904037  NAD83                 3.04        37.0
# 3     36.032955 -78.904037  NAD83                 3.04        37.0
# 4     36.032955 -78.904037  NAD83                 3.04        37.0
# 5     36.032955 -78.904037  NAD83                 3.04        37.0
# 6     36.032955 -78.904037  NAD83                 3.04        37.0
# 7     36.032955 -78.904037  NAD83                 3.04        37.0
# 8     36.032955 -78.904037  NAD83                 3.04        37.0
# 9     36.032955 -78.904037  NAD83                 3.04        37.0
# 10    36.032955 -78.904037  NAD83                 3.04        37.0
# 11    36.032955 -78.904037  NAD83                 3.04        37.0
# 12    36.032955 -78.904037  NAD83                 3.04        37.0
# ...

# %%
AQS_raw_url = "https://aqs.epa.gov/api/rawData?"
_username_password = "user=jlhardyphd@gmail.com&pw=orangemouse54"
_format = "&format=DMCSV"
_param ="&param=44201"
_bdate = "&bdate=20170501"
_edate = "&edate=20170503"
_state = "&state=37"
_county = "&county=063"
query_url = AQS_raw_url + _username_password + _format + _param + _bdate + _edate + _state + _county

# %%
df_raw_data = pd.read_csv(query_url)
df_raw_data
# Out:
#        Latitude  Longitude  Datum  Horizontal Accuracy  State Code  \
# 0     36.032955 -78.904037  NAD83                 3.04        37.0
# 1     36.032955 -78.904037  NAD83                 3.04        37.0
# 2     36.032955 -78.904037  NAD83                 3.04        37.0
# 3     36.032955 -78.904037  NAD83                 3.04        37.0
# 4     36.032955 -78.904037  NAD83                 3.04        37.0
# 5     36.032955 -78.904037  NAD83                 3.04        37.0
# 6     36.032955 -78.904037  NAD83                 3.04        37.0
# 7     36.032955 -78.904037  NAD83                 3.04        37.0
# 8     36.032955 -78.904037  NAD83                 3.04        37.0
# 9     36.032955 -78.904037  NAD83                 3.04        37.0
# 10    36.032955 -78.904037  NAD83                 3.04        37.0
# 11    36.032955 -78.904037  NAD83                 3.04        37.0
# 12    36.032955 -78.904037  NAD83                 3.04        37.0
# ...

# %%
query_url
# Out:
# 'https://aqs.epa.gov/api/rawData?user=jlhardyphd@gmail.com&pw=orangemouse54&format=DMCSV&param=44201&bdate=20180123&edate=20180123&state=37&country=063'

# %%
AQS_list_states_url = 'https://aqs.epa.gov/api/list?name=state&resource=rawData'

# %%
df_AQS_list_states = pd.read_csv(AQS_list_states_url, header=None, sep='\t')
df_AQS_list_states
# Out:
#      0                     1
# 0   01               Alabama
# 1   02                Alaska
# 2   04               Arizona
# 3   05              Arkansas
# 4   06            California
# 5   08              Colorado
# 6   09           Connecticut
# 7   10              Delaware
# 8   11  District Of Columbia
# 9   12               Florida
# 10  13               Georgia
# 11  15                Hawaii
# 12  16                 Idaho
# 13  17              Illinois
# 14  18               Indiana
# 15  19                  Iowa
# 16  20                Kansas
# 17  21              Kentucky
# 18  22             Louisiana
# 19  23                 Maine
# 20  24              Maryland
# 21  25         Massachusetts
# 22  26              Michigan
# 23  27             Minnesota
# 24  28           Mississippi
# 25  29              Missouri
# 26  30               Montana
# 27  31              Nebraska
# 28  32                Nevada
# 29  33         New Hampshire
# 30  34            New Jersey
# ...

# %%
AQS_list_param_url = 'https://aqs.epa.gov/api/list?name=param&resource=rawData'

# %%
df_AQS_list_param = pd.read_csv(AQS_list_param_url, header=None, sep='\t')
df_AQS_list_param
# Out:
#           0                                       1
# 0     11101             Suspended particulate (TSP)
# 1     11102          Suspended particulate (TSP) LC
# 2     11103          Benzene soluble organics (TSP)
# 3     11104          Total polynuclear hydrocarbons
# 4     11114                   Windblown particulate
# 5     11121                      Crystalline quartz
# 6     11122                            Cristabalite
# 7     11123                          Asbestos > 5um
# 8     11124                        Asbestos > 0.5um
# 9     11125               Total non-asbestos fibers
# 10    11201                        Soil index (COH)
# 11    11202                        Soil index (RUD)
# 12    11203                           Light scatter
# 13    11204                                   Smoke
# 14    11205                      Soil index (ug/m3)
# 15    11206                   Light scatter (ug/m3)
# 16    11207        Light scatter (miles visibility)
# ...

# %%
list_param_csv_path = '~/Dev/ML/data/AQS_parameter_list.csv'
df_AQS_list_param.to_csv(list_param_csv_path)
